# %%
import pandas as pd

# %%
bestsellers =  pd.read_csv("/work/bestsellers with categories.csv", sep=",", header=0)
bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# info() nos muestra un resumen de nuestro dataset, incluyendo datos como número de columnas, si tiene valores nulos, etc.
bestsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# describe() nos da informacion sobre los datos numericos de nuestro dataset, como mediana, desviacion std, etc.
bestsellers.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
# Nos mostrara los ultimos valores de nuestro dataset, podemos pasarle el numero de elementos como parametro
bestsellers.tail(5)
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
# Funciona de la misma forma que tail() pero con los primeros elementos
bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# La función memory_usage() se utiliza para calcular el uso de memoria de cada columna en el DataFrame bestsellers,
# y el parámetro deep=True indica que se debe incluir el uso de memoria de objetos referenciados en las columnas,
# como por ejemplo, objetos almacenados en celdas de tipo object.

bestsellers.memory_usage(deep=True)
# Out:
# Index          20960
# Name           61353
# Author         39277
# User Rating     4408
# Reviews         4408
# Price           4408
# Year            4408
# Genre          36508
# dtype: int64

# %%
# value_counts() nos contara el numero de veces que un elemento exista
bestsellers["Author"].value_counts()
# Out:
# Jeff Kinney                           12
# Rick Riordan                          11
# Suzanne Collins                       11
# Gary Chapman                          11
# American Psychological Association    10
#                                       ..
# Khaled Hosseini                        1
# Thomas Piketty                         1
# Phil Robertson                         1
# Alex Michaelides                       1
# Celeste Ng                             1
# Name: Author, Length: 248, dtype: int64

# %%
bestsellers.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
bestsellers = bestsellers.append(bestsellers.iloc[0])

# %%
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# drop_duplicates() nos eliminara si existen elementos repetidos en nuestro dataset, podemos pasarle el parametro
# keep="last" para que mantenga el ultimo elementos duplicado y borre los demas.
bestsellers.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# sort_values() ordena el DataFrame por la columna 'Year' en orden descendente (mayor a menor)
bestsellers.sort_values("Year", ascending=False)
# Out:
#                                                   Name                 Author  \
# 179                       If Animals Kissed Good Night      Ann Whitford Paul
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 267             Player's Handbook (Dungeons & Dragons)       Wizards RPG Team
# ..                                                 ...                    ...
# 160                  Have a Little Faith: A True Story            Mitch Albom
# 512                             True Compass: A Memoir      Edward M. Kennedy
# 513               Twilight (The Twilight Saga, Book 1)        Stephenie Meyer
# 78   Divine Soul Mind Body Healing and Transmission...           Zhi Gang Sha
# 459        The Shack: Where Tragedy Confronts Eternity       William P. Young
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f762273-08b7-49e6-9f67-2f78a3f4f391' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
