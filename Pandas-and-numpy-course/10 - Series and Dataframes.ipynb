# %%
import pandas as pd

# %%
psg_players = pd.Series(["Navas", "Mbappe", "Neymar", "Messi"],
    index=[1,7,10,30]
)

# %%
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dict = {1: "Navas", 7: "Mbappe", 10: "Neymar", 30: "Messi"}

# %%
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[1]
# Out:
# 'Navas'

# %%
data = {
    'Player': ['Luis Suárez','Jorge Molina', 'Antonio Puertas', 'Germán Sánchez', 'Luis Milla', 'Luís Manuel Arantes Maximiano'],
    'Number': [9, 23, 10, 6, 5, 1],
    'Height': [185.0, 187.0, 185.0, 187.0, 175.0, 190.0],
    'Goles': [7, 7, 5, 2, 2, 0]
}

# %%
data["Number"]
# Out:
# [9, 23, 10, 6, 5, 1]

# %%
pd.DataFrame(data)
# Out:
#                           Player  Number  Height  Goles
# 0                    Luis Suárez       9   185.0      7
# 1                   Jorge Molina      23   187.0      7
# 2                Antonio Puertas      10   185.0      5
# 3                 Germán Sánchez       6   187.0      2
# 4                     Luis Milla       5   175.0      2
# 5  Luís Manuel Arantes Maximiano       1   190.0      0

# %%
df_players = pd.DataFrame(data)

# %%
df_players.columns
# Out:
# Index(['Player', 'Number', 'Height', 'Goles'], dtype='object')

# %%
df_players.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df_players
# Out:
#                           Player  Number  Height  Goles
# 0                    Luis Suárez       9   185.0      7
# 1                   Jorge Molina      23   187.0      7
# 2                Antonio Puertas      10   185.0      5
# 3                 Germán Sánchez       6   187.0      2
# 4                     Luis Milla       5   175.0      2
# 5  Luís Manuel Arantes Maximiano       1   190.0      0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f762273-08b7-49e6-9f67-2f78a3f4f391' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
